# %% [markdown]
# # Wordcount analysis example (load from CSV)
#
# This notebook shows the classic wordcount example in which we want to analyze word counting results.

# %%
# To find out where the pyspark
import findspark
findspark.init()

# %%
# Creating Spark Context
from pyspark import SparkContext
sc = SparkContext("local", "Wordcount_rdd_analysis")
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by org.apache.spark.unsafe.Platform (file:/opt/spark/jars/spark-unsafe_2.13-3.2.4.jar) to constructor java.nio.DirectByteBuffer(long,int)
# WARNING: Please consider reporting this to the maintainers of org.apache.spark.unsafe.Platform
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release

# %% [markdown]
# With the step below we are going to read an input (local) file that will be our data source. textFile() and wholeTextFiles() methods to read into RDD that are the low level data access of Spark (there exist other method to read directly in Dataframe).
#
# Each line of the text file is a *row*. We can apply a series of chained operation:
# 1. flatMap produces a new dataset <word> from the splitting
# 2. map produces a new dataset in the form <word, couunt>
# 3. reduceByKey coordinates the aggregation by summing rows with the same key

# %%
sc
# Out:
# <SparkContext master=local appName=Wordcount_rdd_analysis>

# %%
# Calculating words count
csv_file = sc.textFile("output_csv/part-00000")

# %%
csv_file.collect()
# Out:
# ['brand-logo,2',
#  'Homepage,2',
#  'Chi,5',
#  'siamo,5',
#  'Soluzioni,2',
#  'Lavora,4',
#  'con,11',
#  'noi,4',
#  'Contatti,2',
#  'Newsroom,2',
#  'Scopri,5',
#  'le,9',
#  'offerte,5',
#  'Lo,2',
#  'shopping,6',
#  'è,4',
#  'la,11',
#  'nostra,4',
#  'passione.,2',
#  'Vogliamo,2',
#  'arricchire,2',
#  'questa,2',
#  'esperienza,2',
#  'dalla,2',
#  'fase,2',
#  'di,30',
#  'preparazione,2',
#  'su,3',
#  'mobile,3',
#  'fino,4',
#  'al,5',
#  'momento,2',
#  'della,2',
#  'visita,2',
#  'in,21',
#  'negozio.,5',
#  ',49',
#  'Shopping,1',
#  'Experts,1',
#  'a,7',
#  'partire,1',
#  'Ci,1',
#  'impegniamo,1',
#  'fondo,1',
#  'per,7',
#  'offrire,1',
#  'ai,3',
#  'nostri,3',
#  'shopper,1',
#  'sempre,2',
#  'migliore,3',
#  'esperienza:,1',
#  'semplice,,1',
#  'efficace,2',
#  'e,12',
#  'divertente.,1',
#  'Collaboriamo,2',
#  'numerosi,1',
#  'retailers,4',
#  'manufacturers,2',
#  'fine,1',
#  'condurre,1',
#  'più,7',
#  'gli,2',
#  'shoppers,4',
#  'Tech,1',
#  'Lovers,1',
#  'Crediamo,1',
#  'che,3',
#  'tecnologia,1',
#  'possa,1',
#  'realmente,1',
#  'supportare,2',
#  'i,6',
#  'nel,3',
#  'guidare,1',
#  'il,9',
#  'processo,1',
#  'trasformazione,2',
#  'atto,1',
#  'delle,3',
#  'modalità,1',
#  'cui,3',
#  'consumatori,1',
#  'affrontano,1',
#  'lo,2',
#  'shopping.,1',
#  'La,3',
#  'piattaforma,,1',
#  'grazie,2',
#  'big,1',
#  'data,1',
#  'all’uso,1',
#  'del,6',
#  'machine,1',
#  'learning,,1',
#  'cerca,1',
#  'ogni,1',
#  'giorno,1',
#  'modo,2',
#  'connettere,1',
#  'milioni,7',
#  'negozi,4',
#  'consumatori.,1',
#  'Entrepreneurs,1',
#  'Siamo,2',
#  'riconosciuti,1',
#  'Europa,1',
#  'come,2',
#  'una,2',
#  'aziende,1',
#  'crescita,1',
#  'veloce,1',
#  '2017,1',
#  '2018,2',
#  '(Inc.,1',
#  '5000,1',
#  'and,2',
#  'FT),,1',
#  'ma,1',
#  'abbiamo,1',
#  'ancora,1',
#  'molta,1',
#  'strada,1',
#  'da,2',
#  'fare.,1',
#  'prima,1',
#  'regola,1',
#  'raggiungere,2',
#  'obiettivi,1',
#  'concentrarsi,1',
#  'sulla,1',
#  'creazione,1',
#  'misurazione,1',
#  'valore,1',
#  'tutto,2',
#  'quello,1',
#  'facciamo.,1',
#  'International,2',
#  'Abbiamo,1',
#  'un’anima,1',
#  'internazionale.,1',
#  'Puntiamo,1',
#  'retail,1',
#  'mondo,1',
#  'proponendo,1',
#  'soluzioni,1',
#  'globali.,1',
#  'Per,2',
#  'far,1',
#  'questo,2',
#  'facciamo,1',
#  'affidamento,1',
#  'un,1',
#  'team,2',
#  'internazionale,1',
#  '200,1',
#  'professionisti,2',
#  '16,1',
#  'differenti,1',
#  'nazionalità,,1',
#  'operando,1',
#  '6,2',
#  'uffici,2',
#  'distribuiti,1',
#  'Europa,,1',
#  'Apac,1',
#  'Latam.,1',
#  'Il,2',
#  'nostro,4',
#  'management,1',
#  'user-photo,8',
#  'Stefano,2',
#  'Portu,1',
#  'CEO,1',
#  '&,8',
#  'Founder,1',
#  'Paolo,1',
#  'Gargiulo,1',
#  'HR,1',
#  'Director,1',
#  'Marco,2',
#  'Brambilla,1',
#  'Chief,1',
#  'Technology,1',
#  'Officer,1',
#  'Daniele,1',
#  'Antidormi,1',
#  'VP,3',
#  'Business,1',
#  'Solutions,1',
#  'Davide,1',
#  'D’Alena,1',
#  'Sales,2',
#  'Marketing,3',
#  'Durante,1',
#  'Italy,1',
#  'Clineu,1',
#  'Fernandes,1',
#  'Junior,1',
#  'Country,2',
#  'Manager,2',
#  'LATAM,1',
#  'Dean,1',
#  'Vocisano,1',
#  'Australia,1',
#  'Ready,2',
#  'to,4',
#  'get,2',
#  'started?,2',
#  'Contact,1',
#  'Us,1',
#  'Company,2',
#  'Board,4',
#  'Advisory,2',
#  'Corporate,2',
#  'Governance,2',
#  'Resources,2',
#  'Terms,2',
#  'Conditions,2',
#  'Privacy,2',
#  'Policy,2',
#  'Inglese,2',
#  'Italiano,2',
#  'Spagnolo,2',
#  'Portoghese,2',
#  '©,2',
#  '2020,5',
#  'DoveConviene,3',
#  'S.R.L.,2',
#  'VAT,2',
#  'IT03156531208.,2',
#  'Designed,2',
#  'by,2',
#  'Moze,2',
#  'Mobile,1',
#  'Store,1',
#  'Miglioriamo,1',
#  'experience,1',
#  'nei,4',
#  'fisici,2',
#  'attraverso,2',
#  'tecnologie,1',
#  'digitali.,1',
#  'retailer,1',
#  'livello,1',
#  'mondiale,1',
#  'generare,1',
#  'traffico,1',
#  'Più,1',
#  '50,1',
#  'persone,1',
#  'consultano,1',
#  'geolocalizzate,1',
#  'cataloghi,1',
#  'interattivi,1',
#  'ed,2',
#  'formati,1',
#  'slide-to-store,1',
#  'push,1',
#  'proximity.,1',
#  'Una,1',
#  'volta,1',
#  'trovato,1',
#  'ciò,1',
#  'hanno,2',
#  'bisogno,,1',
#  'possono,1',
#  'aggiungerlo,1',
#  'preferiti,1',
#  'attivare,1',
#  'notifica,1',
#  'remind,1',
#  'li,1',
#  'avviserà,1',
#  'quando,1',
#  'saranno,1',
#  'vicini,1',
#  'allo,1',
#  'store,2',
#  'valida,1',
#  'l’offerta,1',
#  'salvata,,1',
#  'guidandoli,1',
#  'quindi,1',
#  'all’ingresso,2',
#  'google,1',
#  'play,1',
#  'app,2',
#  'Molto,2',
#  'utile,2',
#  'stars,6',
#  'ben,1',
#  'fatta,,1',
#  'molto,1',
#  'preparare,1',
#  'tutti,1',
#  'tipi,1',
#  'negozio,,1',
#  'controllare,1',
#  'promozioni.,1',
#  '—,6',
#  'MI,1',
#  '🇮🇹,2',
#  'Top,1',
#  'App,1',
#  'L’unica,1',
#  'applicazione,1',
#  'tipo,1',
#  'dove,1',
#  'puoi,1',
#  'raccogliere,1',
#  'velocemente,1',
#  'informazioni,1',
#  'circa,1',
#  'ultime,1',
#  'volantini,1',
#  'nella,1',
#  'tua,1',
#  'zona,1',
#  'Gabr37ele,1',
#  'Love,2',
#  'it,4',
#  "I'd,1",
#  'rather,1',
#  'have,1',
#  'ShopFully,3',
#  'than,1',
#  'junk,1',
#  'mail,1',
#  'I,8',
#  'just,1',
#  'put,1',
#  'the,3',
#  'bin,1',
#  'each,1',
#  'week.,1',
#  'Ic,1',
#  'covers,1',
#  'all,1',
#  'my,1',
#  'needs,1',
#  'when,1',
#  'want,1',
#  'them.,1',
#  'Thanks,1',
#  'for,2',
#  'great,2',
#  'App.,1',
#  'Pebs57,1',
#  '🇧🇷,1',
#  'Really,1',
#  'good,1',
#  'this,1',
#  'app,,1',
#  'use,1',
#  'every,1',
#  'week,1',
#  'deals,1',
#  'on,1',
#  'pretty,1',
#  'much,1',
#  'everything,1',
#  'anywhere,1',
#  'want.,1',
#  'Thanks.,1',
#  'Sunnypunjab,1',
#  '🇦🇺,2',
#  'Very,1',
#  'useful,2',
#  'can,2',
#  'not,1',
#  'do,1',
#  'without,1',
#  'anymore,,1',
#  "it's,1",
#  'find,1',
#  'best,1',
#  'offers,1',
#  'win.,1',
#  'Stefyx74,1',
#  'Helpful,1',
#  'It,1',
#  'is,3',
#  'very,1',
#  'application.,1',
#  'In,1',
#  'addition,1',
#  'also,1',
#  'an,1',
#  'ecological,1',
#  'measure,1',
#  'because,1',
#  'paper,1',
#  'saved.,1',
#  'love!!!,1',
#  'Lolilo6411,1',
#  '🇲🇽,1',
#  'iphone,1',
#  'image,1',
#  'Retail,1',
#  'solutions,2',
#  'piattaforma,1',
#  'offre,1',
#  'centinaia,1',
#  'soluzione,2',
#  'loro,1',
#  'promozioni,,1',
#  'generando,1',
#  'visite,2',
#  'negozio,3',
#  'misurabili.,1',
#  'Shopper,1',
#  'brands,,1',
#  'advertising,1',
#  'profilato,,1',
#  'grado,1',
#  'influenzare,1',
#  'percorso,1',
#  'acquisto,1',
#  'consumatore,,1',
#  'fin,1',
#  'dentro,1',
#  'fisico.,1',
#  'Measurement,1',
#  'dati,1',
#  'sono,1',
#  'motore,1',
#  'business.,1',
#  'esperti,1',
#  'dello,1',
#  'omnicanale,1',
#  'alla,2',
#  'capacità,1',
#  'prevedere,1',
#  'misurare,1',
#  'comportamento,1',
#  'dall’esposizione,1',
#  'messaggio,1',
#  'pubblicitario,1',
#  'successo,1',
#  'numeri,1',
#  'slideshow,6',
#  'Paesi,1',
#  'attivi,1',
#  'nazionalità,1',
#  'clienti,1',
#  'scelto,1',
#  'partner,1',
#  'raggiunti,1',
#  'monitorate,1',
#  'Dal,1',
#  'blog,1',
#  'blog-post-thumb,3',
#  'dm,1',
#  'sceglie,1',
#  'invitare,1',
#  'scoprire,1',
#  'propria,1',
#  'offerta,1',
#  'geolocalizzato,1',
#  '\ufeff,1',
#  'Aprile,1',
#  '3,,1',
#  'Premiati,1',
#  '60,1',
#  'prodotti,1',
#  'innovativi,1',
#  '15a,1',
#  'edizione,1',
#  'italiana,1',
#  'Eletto,1',
#  'Prodotto,1',
#  'Dell’Anno:,1',
#  'oggi,1',
#  'pa...,1',
#  'Marzo,2',
#  '23,,1',
#  'Coronavirus:,1',
#  'boom,1',
#  'chi,1',
#  'fa,1',
#  'spesa,1',
#  'lunedì,1',
#  'martedì,1',
#  'mattina,,1',
#  'calo,1',
#  '-60%,1',
#  'weekend,1',
#  '19,,1',
#  'Contattaci,1']

# %%
def mysplit(line):
    parts = line.split(",")
    return (parts[0], parts[1])

content = csv_file.map(mysplit)

# %%
len(content.collect())
content.collect()

# Note the output. The value number is a string.. we want a number. You can modify mysplit func to cast second value to a float
# Out:
# [('brand-logo', '2'),
#  ('Homepage', '2'),
#  ('Chi', '5'),
#  ('siamo', '5'),
#  ('Soluzioni', '2'),
#  ('Lavora', '4'),
#  ('con', '11'),
#  ('noi', '4'),
#  ('Contatti', '2'),
#  ('Newsroom', '2'),
#  ('Scopri', '5'),
#  ('le', '9'),
#  ('offerte', '5'),
#  ('Lo', '2'),
#  ('shopping', '6'),
#  ('è', '4'),
#  ('la', '11'),
#  ('nostra', '4'),
#  ('passione.', '2'),
#  ('Vogliamo', '2'),
#  ('arricchire', '2'),
#  ('questa', '2'),
#  ('esperienza', '2'),
#  ('dalla', '2'),
#  ('fase', '2'),
#  ('di', '30'),
#  ('preparazione', '2'),
#  ('su', '3'),
#  ('mobile', '3'),
#  ('fino', '4'),
#  ('al', '5'),
#  ('momento', '2'),
#  ('della', '2'),
#  ('visita', '2'),
#  ('in', '21'),
#  ('negozio.', '5'),
#  ('', '49'),
#  ('Shopping', '1'),
#  ('Experts', '1'),
#  ('a', '7'),
#  ('partire', '1'),
#  ('Ci', '1'),
#  ('impegniamo', '1'),
#  ('fondo', '1'),
#  ('per', '7'),
#  ('offrire', '1'),
#  ('ai', '3'),
#  ('nostri', '3'),
#  ('shopper', '1'),
#  ('sempre', '2'),
#  ('migliore', '3'),
#  ('esperienza:', '1'),
#  ('semplice', ''),
#  ('efficace', '2'),
#  ('e', '12'),
#  ('divertente.', '1'),
#  ('Collaboriamo', '2'),
#  ('numerosi', '1'),
#  ('retailers', '4'),
#  ('manufacturers', '2'),
#  ('fine', '1'),
#  ('condurre', '1'),
#  ('più', '7'),
#  ('gli', '2'),
#  ('shoppers', '4'),
#  ('Tech', '1'),
#  ('Lovers', '1'),
#  ('Crediamo', '1'),
#  ('che', '3'),
#  ('tecnologia', '1'),
#  ('possa', '1'),
#  ('realmente', '1'),
#  ('supportare', '2'),
#  ('i', '6'),
#  ('nel', '3'),
#  ('guidare', '1'),
#  ('il', '9'),
#  ('processo', '1'),
#  ('trasformazione', '2'),
#  ('atto', '1'),
#  ('delle', '3'),
#  ('modalità', '1'),
#  ('cui', '3'),
#  ('consumatori', '1'),
#  ('affrontano', '1'),
#  ('lo', '2'),
#  ('shopping.', '1'),
#  ('La', '3'),
#  ('piattaforma', ''),
#  ('grazie', '2'),
#  ('big', '1'),
#  ('data', '1'),
#  ('all’uso', '1'),
#  ('del', '6'),
#  ('machine', '1'),
#  ('learning', ''),
#  ('cerca', '1'),
#  ('ogni', '1'),
#  ('giorno', '1'),
#  ('modo', '2'),
#  ('connettere', '1'),
#  ('milioni', '7'),
#  ('negozi', '4'),
#  ('consumatori.', '1'),
#  ('Entrepreneurs', '1'),
#  ('Siamo', '2'),
#  ('riconosciuti', '1'),
#  ('Europa', '1'),
#  ('come', '2'),
#  ('una', '2'),
#  ('aziende', '1'),
#  ('crescita', '1'),
#  ('veloce', '1'),
#  ('2017', '1'),
#  ('2018', '2'),
#  ('(Inc.', '1'),
#  ('5000', '1'),
#  ('and', '2'),
#  ('FT)', ''),
#  ('ma', '1'),
#  ('abbiamo', '1'),
#  ('ancora', '1'),
#  ('molta', '1'),
#  ('strada', '1'),
#  ('da', '2'),
#  ('fare.', '1'),
#  ('prima', '1'),
#  ('regola', '1'),
#  ('raggiungere', '2'),
#  ('obiettivi', '1'),
#  ('concentrarsi', '1'),
#  ('sulla', '1'),
#  ('creazione', '1'),
#  ('misurazione', '1'),
#  ('valore', '1'),
#  ('tutto', '2'),
#  ('quello', '1'),
#  ('facciamo.', '1'),
#  ('International', '2'),
#  ('Abbiamo', '1'),
#  ('un’anima', '1'),
#  ('internazionale.', '1'),
#  ('Puntiamo', '1'),
#  ('retail', '1'),
#  ('mondo', '1'),
#  ('proponendo', '1'),
#  ('soluzioni', '1'),
#  ('globali.', '1'),
#  ('Per', '2'),
#  ('far', '1'),
#  ('questo', '2'),
#  ('facciamo', '1'),
#  ('affidamento', '1'),
#  ('un', '1'),
#  ('team', '2'),
#  ('internazionale', '1'),
#  ('200', '1'),
#  ('professionisti', '2'),
#  ('16', '1'),
#  ('differenti', '1'),
#  ('nazionalità', ''),
#  ('operando', '1'),
#  ('6', '2'),
#  ('uffici', '2'),
#  ('distribuiti', '1'),
#  ('Europa', ''),
#  ('Apac', '1'),
#  ('Latam.', '1'),
#  ('Il', '2'),
#  ('nostro', '4'),
#  ('management', '1'),
#  ('user-photo', '8'),
#  ('Stefano', '2'),
#  ('Portu', '1'),
#  ('CEO', '1'),
#  ('&', '8'),
#  ('Founder', '1'),
#  ('Paolo', '1'),
#  ('Gargiulo', '1'),
#  ('HR', '1'),
#  ('Director', '1'),
#  ('Marco', '2'),
#  ('Brambilla', '1'),
#  ('Chief', '1'),
#  ('Technology', '1'),
#  ('Officer', '1'),
#  ('Daniele', '1'),
#  ('Antidormi', '1'),
#  ('VP', '3'),
#  ('Business', '1'),
#  ('Solutions', '1'),
#  ('Davide', '1'),
#  ('D’Alena', '1'),
#  ('Sales', '2'),
#  ('Marketing', '3'),
#  ('Durante', '1'),
#  ('Italy', '1'),
#  ('Clineu', '1'),
#  ('Fernandes', '1'),
#  ('Junior', '1'),
#  ('Country', '2'),
#  ('Manager', '2'),
#  ('LATAM', '1'),
#  ('Dean', '1'),
#  ('Vocisano', '1'),
#  ('Australia', '1'),
#  ('Ready', '2'),
#  ('to', '4'),
#  ('get', '2'),
#  ('started?', '2'),
#  ('Contact', '1'),
#  ('Us', '1'),
#  ('Company', '2'),
#  ('Board', '4'),
#  ('Advisory', '2'),
#  ('Corporate', '2'),
#  ('Governance', '2'),
#  ('Resources', '2'),
#  ('Terms', '2'),
#  ('Conditions', '2'),
#  ('Privacy', '2'),
#  ('Policy', '2'),
#  ('Inglese', '2'),
#  ('Italiano', '2'),
#  ('Spagnolo', '2'),
#  ('Portoghese', '2'),
#  ('©', '2'),
#  ('2020', '5'),
#  ('DoveConviene', '3'),
#  ('S.R.L.', '2'),
#  ('VAT', '2'),
#  ('IT03156531208.', '2'),
#  ('Designed', '2'),
#  ('by', '2'),
#  ('Moze', '2'),
#  ('Mobile', '1'),
#  ('Store', '1'),
#  ('Miglioriamo', '1'),
#  ('experience', '1'),
#  ('nei', '4'),
#  ('fisici', '2'),
#  ('attraverso', '2'),
#  ('tecnologie', '1'),
#  ('digitali.', '1'),
#  ('retailer', '1'),
#  ('livello', '1'),
#  ('mondiale', '1'),
#  ('generare', '1'),
#  ('traffico', '1'),
#  ('Più', '1'),
#  ('50', '1'),
#  ('persone', '1'),
#  ('consultano', '1'),
#  ('geolocalizzate', '1'),
#  ('cataloghi', '1'),
#  ('interattivi', '1'),
#  ('ed', '2'),
#  ('formati', '1'),
#  ('slide-to-store', '1'),
#  ('push', '1'),
#  ('proximity.', '1'),
#  ('Una', '1'),
#  ('volta', '1'),
#  ('trovato', '1'),
#  ('ciò', '1'),
#  ('hanno', '2'),
#  ('bisogno', ''),
#  ('possono', '1'),
#  ('aggiungerlo', '1'),
#  ('preferiti', '1'),
#  ('attivare', '1'),
#  ('notifica', '1'),
#  ('remind', '1'),
#  ('li', '1'),
#  ('avviserà', '1'),
#  ('quando', '1'),
#  ('saranno', '1'),
#  ('vicini', '1'),
#  ('allo', '1'),
#  ('store', '2'),
#  ('valida', '1'),
#  ('l’offerta', '1'),
#  ('salvata', ''),
#  ('guidandoli', '1'),
#  ('quindi', '1'),
#  ('all’ingresso', '2'),
#  ('google', '1'),
#  ('play', '1'),
#  ('app', '2'),
#  ('Molto', '2'),
#  ('utile', '2'),
#  ('stars', '6'),
#  ('ben', '1'),
#  ('fatta', ''),
#  ('molto', '1'),
#  ('preparare', '1'),
#  ('tutti', '1'),
#  ('tipi', '1'),
#  ('negozio', ''),
#  ('controllare', '1'),
#  ('promozioni.', '1'),
#  ('—', '6'),
#  ('MI', '1'),
#  ('🇮🇹', '2'),
#  ('Top', '1'),
#  ('App', '1'),
#  ('L’unica', '1'),
#  ('applicazione', '1'),
#  ('tipo', '1'),
#  ('dove', '1'),
#  ('puoi', '1'),
#  ('raccogliere', '1'),
#  ('velocemente', '1'),
#  ('informazioni', '1'),
#  ('circa', '1'),
#  ('ultime', '1'),
#  ('volantini', '1'),
#  ('nella', '1'),
#  ('tua', '1'),
#  ('zona', '1'),
#  ('Gabr37ele', '1'),
#  ('Love', '2'),
#  ('it', '4'),
#  ("I'd", '1'),
#  ('rather', '1'),
#  ('have', '1'),
#  ('ShopFully', '3'),
#  ('than', '1'),
#  ('junk', '1'),
#  ('mail', '1'),
#  ('I', '8'),
#  ('just', '1'),
#  ('put', '1'),
#  ('the', '3'),
#  ('bin', '1'),
#  ('each', '1'),
#  ('week.', '1'),
#  ('Ic', '1'),
#  ('covers', '1'),
#  ('all', '1'),
#  ('my', '1'),
#  ('needs', '1'),
#  ('when', '1'),
#  ('want', '1'),
#  ('them.', '1'),
#  ('Thanks', '1'),
#  ('for', '2'),
#  ('great', '2'),
#  ('App.', '1'),
#  ('Pebs57', '1'),
#  ('🇧🇷', '1'),
#  ('Really', '1'),
#  ('good', '1'),
#  ('this', '1'),
#  ('app', ''),
#  ('use', '1'),
#  ('every', '1'),
#  ('week', '1'),
#  ('deals', '1'),
#  ('on', '1'),
#  ('pretty', '1'),
#  ('much', '1'),
#  ('everything', '1'),
#  ('anywhere', '1'),
#  ('want.', '1'),
#  ('Thanks.', '1'),
#  ('Sunnypunjab', '1'),
#  ('🇦🇺', '2'),
#  ('Very', '1'),
#  ('useful', '2'),
#  ('can', '2'),
#  ('not', '1'),
#  ('do', '1'),
#  ('without', '1'),
#  ('anymore', ''),
#  ("it's", '1'),
#  ('find', '1'),
#  ('best', '1'),
#  ('offers', '1'),
#  ('win.', '1'),
#  ('Stefyx74', '1'),
#  ('Helpful', '1'),
#  ('It', '1'),
#  ('is', '3'),
#  ('very', '1'),
#  ('application.', '1'),
#  ('In', '1'),
#  ('addition', '1'),
#  ('also', '1'),
#  ('an', '1'),
#  ('ecological', '1'),
#  ('measure', '1'),
#  ('because', '1'),
#  ('paper', '1'),
#  ('saved.', '1'),
#  ('love!!!', '1'),
#  ('Lolilo6411', '1'),
#  ('🇲🇽', '1'),
#  ('iphone', '1'),
#  ('image', '1'),
#  ('Retail', '1'),
#  ('solutions', '2'),
#  ('piattaforma', '1'),
#  ('offre', '1'),
#  ('centinaia', '1'),
#  ('soluzione', '2'),
#  ('loro', '1'),
#  ('promozioni', ''),
#  ('generando', '1'),
#  ('visite', '2'),
#  ('negozio', '3'),
#  ('misurabili.', '1'),
#  ('Shopper', '1'),
#  ('brands', ''),
#  ('advertising', '1'),
#  ('profilato', ''),
#  ('grado', '1'),
#  ('influenzare', '1'),
#  ('percorso', '1'),
#  ('acquisto', '1'),
#  ('consumatore', ''),
#  ('fin', '1'),
#  ('dentro', '1'),
#  ('fisico.', '1'),
#  ('Measurement', '1'),
#  ('dati', '1'),
#  ('sono', '1'),
#  ('motore', '1'),
#  ('business.', '1'),
#  ('esperti', '1'),
#  ('dello', '1'),
#  ('omnicanale', '1'),
#  ('alla', '2'),
#  ('capacità', '1'),
#  ('prevedere', '1'),
#  ('misurare', '1'),
#  ('comportamento', '1'),
#  ('dall’esposizione', '1'),
#  ('messaggio', '1'),
#  ('pubblicitario', '1'),
#  ('successo', '1'),
#  ('numeri', '1'),
#  ('slideshow', '6'),
#  ('Paesi', '1'),
#  ('attivi', '1'),
#  ('nazionalità', '1'),
#  ('clienti', '1'),
#  ('scelto', '1'),
#  ('partner', '1'),
#  ('raggiunti', '1'),
#  ('monitorate', '1'),
#  ('Dal', '1'),
#  ('blog', '1'),
#  ('blog-post-thumb', '3'),
#  ('dm', '1'),
#  ('sceglie', '1'),
#  ('invitare', '1'),
#  ('scoprire', '1'),
#  ('propria', '1'),
#  ('offerta', '1'),
#  ('geolocalizzato', '1'),
#  ('\ufeff', '1'),
#  ('Aprile', '1'),
#  ('3', ''),
#  ('Premiati', '1'),
#  ('60', '1'),
#  ('prodotti', '1'),
#  ('innovativi', '1'),
#  ('15a', '1'),
#  ('edizione', '1'),
#  ('italiana', '1'),
#  ('Eletto', '1'),
#  ('Prodotto', '1'),
#  ('Dell’Anno:', '1'),
#  ('oggi', '1'),
#  ('pa...', '1'),
#  ('Marzo', '2'),
#  ('23', ''),
#  ('Coronavirus:', '1'),
#  ('boom', '1'),
#  ('chi', '1'),
#  ('fa', '1'),
#  ('spesa', '1'),
#  ('lunedì', '1'),
#  ('martedì', '1'),
#  ('mattina', ''),
#  ('calo', '1'),
#  ('-60%', '1'),
#  ('weekend', '1'),
#  ('19', ''),
#  ('Contattaci', '1')]

# %%
# The second argument can be empty due to some formatting problem.. casting to float can rise an error.
# You can handle work values in the function, or do a filteing before..

def myfilter(tuple_rdd):
    if tuple_rdd[0] == '' or tuple_rdd[1] == '' :
        print("Skip line")
        return False
    else:
        return True

content2 = content.filter(myfilter)
len(content2.collect())
# Now you can add cast to float
# Out:
# 470

# %%
def cast_rdd(tuple_rdd):
    return (tuple_rdd[0], float(tuple_rdd[1]))

content3 = content2.map(cast_rdd)
content3.collect()
# Out:
# [('brand-logo', 2.0),
#  ('Homepage', 2.0),
#  ('Chi', 5.0),
#  ('siamo', 5.0),
#  ('Soluzioni', 2.0),
#  ('Lavora', 4.0),
#  ('con', 11.0),
#  ('noi', 4.0),
#  ('Contatti', 2.0),
#  ('Newsroom', 2.0),
#  ('Scopri', 5.0),
#  ('le', 9.0),
#  ('offerte', 5.0),
#  ('Lo', 2.0),
#  ('shopping', 6.0),
#  ('è', 4.0),
#  ('la', 11.0),
#  ('nostra', 4.0),
#  ('passione.', 2.0),
#  ('Vogliamo', 2.0),
#  ('arricchire', 2.0),
#  ('questa', 2.0),
#  ('esperienza', 2.0),
#  ('dalla', 2.0),
#  ('fase', 2.0),
#  ('di', 30.0),
#  ('preparazione', 2.0),
#  ('su', 3.0),
#  ('mobile', 3.0),
#  ('fino', 4.0),
#  ('al', 5.0),
#  ('momento', 2.0),
#  ('della', 2.0),
#  ('visita', 2.0),
#  ('in', 21.0),
#  ('negozio.', 5.0),
#  ('Shopping', 1.0),
#  ('Experts', 1.0),
#  ('a', 7.0),
#  ('partire', 1.0),
#  ('Ci', 1.0),
#  ('impegniamo', 1.0),
#  ('fondo', 1.0),
#  ('per', 7.0),
#  ('offrire', 1.0),
#  ('ai', 3.0),
#  ('nostri', 3.0),
#  ('shopper', 1.0),
#  ('sempre', 2.0),
#  ('migliore', 3.0),
#  ('esperienza:', 1.0),
#  ('efficace', 2.0),
#  ('e', 12.0),
#  ('divertente.', 1.0),
#  ('Collaboriamo', 2.0),
#  ('numerosi', 1.0),
#  ('retailers', 4.0),
#  ('manufacturers', 2.0),
#  ('fine', 1.0),
#  ('condurre', 1.0),
#  ('più', 7.0),
#  ('gli', 2.0),
#  ('shoppers', 4.0),
#  ('Tech', 1.0),
#  ('Lovers', 1.0),
#  ('Crediamo', 1.0),
#  ('che', 3.0),
#  ('tecnologia', 1.0),
#  ('possa', 1.0),
#  ('realmente', 1.0),
#  ('supportare', 2.0),
#  ('i', 6.0),
#  ('nel', 3.0),
#  ('guidare', 1.0),
#  ('il', 9.0),
#  ('processo', 1.0),
#  ('trasformazione', 2.0),
#  ('atto', 1.0),
#  ('delle', 3.0),
#  ('modalità', 1.0),
#  ('cui', 3.0),
#  ('consumatori', 1.0),
#  ('affrontano', 1.0),
#  ('lo', 2.0),
#  ('shopping.', 1.0),
#  ('La', 3.0),
#  ('grazie', 2.0),
#  ('big', 1.0),
#  ('data', 1.0),
#  ('all’uso', 1.0),
#  ('del', 6.0),
#  ('machine', 1.0),
#  ('cerca', 1.0),
#  ('ogni', 1.0),
#  ('giorno', 1.0),
#  ('modo', 2.0),
#  ('connettere', 1.0),
#  ('milioni', 7.0),
#  ('negozi', 4.0),
#  ('consumatori.', 1.0),
#  ('Entrepreneurs', 1.0),
#  ('Siamo', 2.0),
#  ('riconosciuti', 1.0),
#  ('Europa', 1.0),
#  ('come', 2.0),
#  ('una', 2.0),
#  ('aziende', 1.0),
#  ('crescita', 1.0),
#  ('veloce', 1.0),
#  ('2017', 1.0),
#  ('2018', 2.0),
#  ('(Inc.', 1.0),
#  ('5000', 1.0),
#  ('and', 2.0),
#  ('ma', 1.0),
#  ('abbiamo', 1.0),
#  ('ancora', 1.0),
#  ('molta', 1.0),
#  ('strada', 1.0),
#  ('da', 2.0),
#  ('fare.', 1.0),
#  ('prima', 1.0),
#  ('regola', 1.0),
#  ('raggiungere', 2.0),
#  ('obiettivi', 1.0),
#  ('concentrarsi', 1.0),
#  ('sulla', 1.0),
#  ('creazione', 1.0),
#  ('misurazione', 1.0),
#  ('valore', 1.0),
#  ('tutto', 2.0),
#  ('quello', 1.0),
#  ('facciamo.', 1.0),
#  ('International', 2.0),
#  ('Abbiamo', 1.0),
#  ('un’anima', 1.0),
#  ('internazionale.', 1.0),
#  ('Puntiamo', 1.0),
#  ('retail', 1.0),
#  ('mondo', 1.0),
#  ('proponendo', 1.0),
#  ('soluzioni', 1.0),
#  ('globali.', 1.0),
#  ('Per', 2.0),
#  ('far', 1.0),
#  ('questo', 2.0),
#  ('facciamo', 1.0),
#  ('affidamento', 1.0),
#  ('un', 1.0),
#  ('team', 2.0),
#  ('internazionale', 1.0),
#  ('200', 1.0),
#  ('professionisti', 2.0),
#  ('16', 1.0),
#  ('differenti', 1.0),
#  ('operando', 1.0),
#  ('6', 2.0),
#  ('uffici', 2.0),
#  ('distribuiti', 1.0),
#  ('Apac', 1.0),
#  ('Latam.', 1.0),
#  ('Il', 2.0),
#  ('nostro', 4.0),
#  ('management', 1.0),
#  ('user-photo', 8.0),
#  ('Stefano', 2.0),
#  ('Portu', 1.0),
#  ('CEO', 1.0),
#  ('&', 8.0),
#  ('Founder', 1.0),
#  ('Paolo', 1.0),
#  ('Gargiulo', 1.0),
#  ('HR', 1.0),
#  ('Director', 1.0),
#  ('Marco', 2.0),
#  ('Brambilla', 1.0),
#  ('Chief', 1.0),
#  ('Technology', 1.0),
#  ('Officer', 1.0),
#  ('Daniele', 1.0),
#  ('Antidormi', 1.0),
#  ('VP', 3.0),
#  ('Business', 1.0),
#  ('Solutions', 1.0),
#  ('Davide', 1.0),
#  ('D’Alena', 1.0),
#  ('Sales', 2.0),
#  ('Marketing', 3.0),
#  ('Durante', 1.0),
#  ('Italy', 1.0),
#  ('Clineu', 1.0),
#  ('Fernandes', 1.0),
#  ('Junior', 1.0),
#  ('Country', 2.0),
#  ('Manager', 2.0),
#  ('LATAM', 1.0),
#  ('Dean', 1.0),
#  ('Vocisano', 1.0),
#  ('Australia', 1.0),
#  ('Ready', 2.0),
#  ('to', 4.0),
#  ('get', 2.0),
#  ('started?', 2.0),
#  ('Contact', 1.0),
#  ('Us', 1.0),
#  ('Company', 2.0),
#  ('Board', 4.0),
#  ('Advisory', 2.0),
#  ('Corporate', 2.0),
#  ('Governance', 2.0),
#  ('Resources', 2.0),
#  ('Terms', 2.0),
#  ('Conditions', 2.0),
#  ('Privacy', 2.0),
#  ('Policy', 2.0),
#  ('Inglese', 2.0),
#  ('Italiano', 2.0),
#  ('Spagnolo', 2.0),
#  ('Portoghese', 2.0),
#  ('©', 2.0),
#  ('2020', 5.0),
#  ('DoveConviene', 3.0),
#  ('S.R.L.', 2.0),
#  ('VAT', 2.0),
#  ('IT03156531208.', 2.0),
#  ('Designed', 2.0),
#  ('by', 2.0),
#  ('Moze', 2.0),
#  ('Mobile', 1.0),
#  ('Store', 1.0),
#  ('Miglioriamo', 1.0),
#  ('experience', 1.0),
#  ('nei', 4.0),
#  ('fisici', 2.0),
#  ('attraverso', 2.0),
#  ('tecnologie', 1.0),
#  ('digitali.', 1.0),
#  ('retailer', 1.0),
#  ('livello', 1.0),
#  ('mondiale', 1.0),
#  ('generare', 1.0),
#  ('traffico', 1.0),
#  ('Più', 1.0),
#  ('50', 1.0),
#  ('persone', 1.0),
#  ('consultano', 1.0),
#  ('geolocalizzate', 1.0),
#  ('cataloghi', 1.0),
#  ('interattivi', 1.0),
#  ('ed', 2.0),
#  ('formati', 1.0),
#  ('slide-to-store', 1.0),
#  ('push', 1.0),
#  ('proximity.', 1.0),
#  ('Una', 1.0),
#  ('volta', 1.0),
#  ('trovato', 1.0),
#  ('ciò', 1.0),
#  ('hanno', 2.0),
#  ('possono', 1.0),
#  ('aggiungerlo', 1.0),
#  ('preferiti', 1.0),
#  ('attivare', 1.0),
#  ('notifica', 1.0),
#  ('remind', 1.0),
#  ('li', 1.0),
#  ('avviserà', 1.0),
#  ('quando', 1.0),
#  ('saranno', 1.0),
#  ('vicini', 1.0),
#  ('allo', 1.0),
#  ('store', 2.0),
#  ('valida', 1.0),
#  ('l’offerta', 1.0),
#  ('guidandoli', 1.0),
#  ('quindi', 1.0),
#  ('all’ingresso', 2.0),
#  ('google', 1.0),
#  ('play', 1.0),
#  ('app', 2.0),
#  ('Molto', 2.0),
#  ('utile', 2.0),
#  ('stars', 6.0),
#  ('ben', 1.0),
#  ('molto', 1.0),
#  ('preparare', 1.0),
#  ('tutti', 1.0),
#  ('tipi', 1.0),
#  ('controllare', 1.0),
#  ('promozioni.', 1.0),
#  ('—', 6.0),
#  ('MI', 1.0),
#  ('🇮🇹', 2.0),
#  ('Top', 1.0),
#  ('App', 1.0),
#  ('L’unica', 1.0),
#  ('applicazione', 1.0),
#  ('tipo', 1.0),
#  ('dove', 1.0),
#  ('puoi', 1.0),
#  ('raccogliere', 1.0),
#  ('velocemente', 1.0),
#  ('informazioni', 1.0),
#  ('circa', 1.0),
#  ('ultime', 1.0),
#  ('volantini', 1.0),
#  ('nella', 1.0),
#  ('tua', 1.0),
#  ('zona', 1.0),
#  ('Gabr37ele', 1.0),
#  ('Love', 2.0),
#  ('it', 4.0),
#  ("I'd", 1.0),
#  ('rather', 1.0),
#  ('have', 1.0),
#  ('ShopFully', 3.0),
#  ('than', 1.0),
#  ('junk', 1.0),
#  ('mail', 1.0),
#  ('I', 8.0),
#  ('just', 1.0),
#  ('put', 1.0),
#  ('the', 3.0),
#  ('bin', 1.0),
#  ('each', 1.0),
#  ('week.', 1.0),
#  ('Ic', 1.0),
#  ('covers', 1.0),
#  ('all', 1.0),
#  ('my', 1.0),
#  ('needs', 1.0),
#  ('when', 1.0),
#  ('want', 1.0),
#  ('them.', 1.0),
#  ('Thanks', 1.0),
#  ('for', 2.0),
#  ('great', 2.0),
#  ('App.', 1.0),
#  ('Pebs57', 1.0),
#  ('🇧🇷', 1.0),
#  ('Really', 1.0),
#  ('good', 1.0),
#  ('this', 1.0),
#  ('use', 1.0),
#  ('every', 1.0),
#  ('week', 1.0),
#  ('deals', 1.0),
#  ('on', 1.0),
#  ('pretty', 1.0),
#  ('much', 1.0),
#  ('everything', 1.0),
#  ('anywhere', 1.0),
#  ('want.', 1.0),
#  ('Thanks.', 1.0),
#  ('Sunnypunjab', 1.0),
#  ('🇦🇺', 2.0),
#  ('Very', 1.0),
#  ('useful', 2.0),
#  ('can', 2.0),
#  ('not', 1.0),
#  ('do', 1.0),
#  ('without', 1.0),
#  ("it's", 1.0),
#  ('find', 1.0),
#  ('best', 1.0),
#  ('offers', 1.0),
#  ('win.', 1.0),
#  ('Stefyx74', 1.0),
#  ('Helpful', 1.0),
#  ('It', 1.0),
#  ('is', 3.0),
#  ('very', 1.0),
#  ('application.', 1.0),
#  ('In', 1.0),
#  ('addition', 1.0),
#  ('also', 1.0),
#  ('an', 1.0),
#  ('ecological', 1.0),
#  ('measure', 1.0),
#  ('because', 1.0),
#  ('paper', 1.0),
#  ('saved.', 1.0),
#  ('love!!!', 1.0),
#  ('Lolilo6411', 1.0),
#  ('🇲🇽', 1.0),
#  ('iphone', 1.0),
#  ('image', 1.0),
#  ('Retail', 1.0),
#  ('solutions', 2.0),
#  ('piattaforma', 1.0),
#  ('offre', 1.0),
#  ('centinaia', 1.0),
#  ('soluzione', 2.0),
#  ('loro', 1.0),
#  ('generando', 1.0),
#  ('visite', 2.0),
#  ('negozio', 3.0),
#  ('misurabili.', 1.0),
#  ('Shopper', 1.0),
#  ('advertising', 1.0),
#  ('grado', 1.0),
#  ('influenzare', 1.0),
#  ('percorso', 1.0),
#  ('acquisto', 1.0),
#  ('fin', 1.0),
#  ('dentro', 1.0),
#  ('fisico.', 1.0),
#  ('Measurement', 1.0),
#  ('dati', 1.0),
#  ('sono', 1.0),
#  ('motore', 1.0),
#  ('business.', 1.0),
#  ('esperti', 1.0),
#  ('dello', 1.0),
#  ('omnicanale', 1.0),
#  ('alla', 2.0),
#  ('capacità', 1.0),
#  ('prevedere', 1.0),
#  ('misurare', 1.0),
#  ('comportamento', 1.0),
#  ('dall’esposizione', 1.0),
#  ('messaggio', 1.0),
#  ('pubblicitario', 1.0),
#  ('successo', 1.0),
#  ('numeri', 1.0),
#  ('slideshow', 6.0),
#  ('Paesi', 1.0),
#  ('attivi', 1.0),
#  ('nazionalità', 1.0),
#  ('clienti', 1.0),
#  ('scelto', 1.0),
#  ('partner', 1.0),
#  ('raggiunti', 1.0),
#  ('monitorate', 1.0),
#  ('Dal', 1.0),
#  ('blog', 1.0),
#  ('blog-post-thumb', 3.0),
#  ('dm', 1.0),
#  ('sceglie', 1.0),
#  ('invitare', 1.0),
#  ('scoprire', 1.0),
#  ('propria', 1.0),
#  ('offerta', 1.0),
#  ('geolocalizzato', 1.0),
#  ('\ufeff', 1.0),
#  ('Aprile', 1.0),
#  ('Premiati', 1.0),
#  ('60', 1.0),
#  ('prodotti', 1.0),
#  ('innovativi', 1.0),
#  ('15a', 1.0),
#  ('edizione', 1.0),
#  ('italiana', 1.0),
#  ('Eletto', 1.0),
#  ('Prodotto', 1.0),
#  ('Dell’Anno:', 1.0),
#  ('oggi', 1.0),
#  ('pa...', 1.0),
#  ('Marzo', 2.0),
#  ('Coronavirus:', 1.0),
#  ('boom', 1.0),
#  ('chi', 1.0),
#  ('fa', 1.0),
#  ('spesa', 1.0),
#  ('lunedì', 1.0),
#  ('martedì', 1.0),
#  ('calo', 1.0),
#  ('-60%', 1.0),
#  ('weekend', 1.0),
#  ('Contattaci', 1.0)]

# %%
#def myfilter_wrong(tuple_rdd):
#    if tuple_rdd[1] == '' :
#        print("Skip line")
#        return True
#    else:
#        return False
#
#content3 = content.filter(myfilter_wrong)
#content3.collect()
#content2 = content3

# %%
output = content3.collect()
for (word, occurs) in output:
    print("%s: %f" % (word, occurs))
# Out:
# brand-logo: 2.000000
# Homepage: 2.000000
# Chi: 5.000000
# siamo: 5.000000
# Soluzioni: 2.000000
# Lavora: 4.000000
# con: 11.000000
# noi: 4.000000
# Contatti: 2.000000
# Newsroom: 2.000000
# Scopri: 5.000000
# le: 9.000000
# offerte: 5.000000
# Lo: 2.000000
# shopping: 6.000000
# è: 4.000000
# la: 11.000000
# nostra: 4.000000
# passione.: 2.000000
# Vogliamo: 2.000000
# arricchire: 2.000000
# questa: 2.000000
# esperienza: 2.000000
# dalla: 2.000000
# fase: 2.000000
# di: 30.000000
# preparazione: 2.000000
# su: 3.000000
# mobile: 3.000000
# fino: 4.000000
# al: 5.000000
# momento: 2.000000
# della: 2.000000
# visita: 2.000000
# in: 21.000000
# negozio.: 5.000000
# Shopping: 1.000000
# Experts: 1.000000
# a: 7.000000
# partire: 1.000000
# Ci: 1.000000
# impegniamo: 1.000000
# fondo: 1.000000
# per: 7.000000
# offrire: 1.000000
# ai: 3.000000
# nostri: 3.000000
# shopper: 1.000000
# sempre: 2.000000
# migliore: 3.000000
# esperienza:: 1.000000
# efficace: 2.000000
# e: 12.000000
# divertente.: 1.000000
# Collaboriamo: 2.000000
# numerosi: 1.000000
# retailers: 4.000000
# manufacturers: 2.000000
# fine: 1.000000
# condurre: 1.000000
# più: 7.000000
# gli: 2.000000
# shoppers: 4.000000
# Tech: 1.000000
# Lovers: 1.000000
# Crediamo: 1.000000
# che: 3.000000
# tecnologia: 1.000000
# possa: 1.000000
# realmente: 1.000000
# supportare: 2.000000
# i: 6.000000
# nel: 3.000000
# guidare: 1.000000
# il: 9.000000
# processo: 1.000000
# trasformazione: 2.000000
# atto: 1.000000
# delle: 3.000000
# modalità: 1.000000
# cui: 3.000000
# consumatori: 1.000000
# affrontano: 1.000000
# lo: 2.000000
# shopping.: 1.000000
# La: 3.000000
# grazie: 2.000000
# big: 1.000000
# data: 1.000000
# all’uso: 1.000000
# del: 6.000000
# machine: 1.000000
# cerca: 1.000000
# ogni: 1.000000
# giorno: 1.000000
# modo: 2.000000
# connettere: 1.000000
# milioni: 7.000000
# negozi: 4.000000
# consumatori.: 1.000000
# Entrepreneurs: 1.000000
# Siamo: 2.000000
# riconosciuti: 1.000000
# Europa: 1.000000
# come: 2.000000
# una: 2.000000
# aziende: 1.000000
# crescita: 1.000000
# veloce: 1.000000
# 2017: 1.000000
# 2018: 2.000000
# (Inc.: 1.000000
# 5000: 1.000000
# and: 2.000000
# ma: 1.000000
# abbiamo: 1.000000
# ancora: 1.000000
# molta: 1.000000
# strada: 1.000000
# da: 2.000000
# fare.: 1.000000
# prima: 1.000000
# regola: 1.000000
# raggiungere: 2.000000
# obiettivi: 1.000000
# concentrarsi: 1.000000
# sulla: 1.000000
# creazione: 1.000000
# misurazione: 1.000000
# valore: 1.000000
# tutto: 2.000000
# quello: 1.000000
# facciamo.: 1.000000
# International: 2.000000
# Abbiamo: 1.000000
# un’anima: 1.000000
# internazionale.: 1.000000
# Puntiamo: 1.000000
# retail: 1.000000
# mondo: 1.000000
# proponendo: 1.000000
# soluzioni: 1.000000
# globali.: 1.000000
# Per: 2.000000
# far: 1.000000
# questo: 2.000000
# facciamo: 1.000000
# affidamento: 1.000000
# un: 1.000000
# team: 2.000000
# internazionale: 1.000000
# 200: 1.000000
# professionisti: 2.000000
# 16: 1.000000
# differenti: 1.000000
# operando: 1.000000
# 6: 2.000000
# uffici: 2.000000
# distribuiti: 1.000000
# Apac: 1.000000
# Latam.: 1.000000
# Il: 2.000000
# nostro: 4.000000
# management: 1.000000
# user-photo: 8.000000
# Stefano: 2.000000
# Portu: 1.000000
# CEO: 1.000000
# &: 8.000000
# Founder: 1.000000
# Paolo: 1.000000
# Gargiulo: 1.000000
# HR: 1.000000
# Director: 1.000000
# Marco: 2.000000
# Brambilla: 1.000000
# Chief: 1.000000
# Technology: 1.000000
# Officer: 1.000000
# Daniele: 1.000000
# Antidormi: 1.000000
# VP: 3.000000
# Business: 1.000000
# Solutions: 1.000000
# Davide: 1.000000
# D’Alena: 1.000000
# Sales: 2.000000
# Marketing: 3.000000
# Durante: 1.000000
# Italy: 1.000000
# Clineu: 1.000000
# Fernandes: 1.000000
# Junior: 1.000000
# Country: 2.000000
# Manager: 2.000000
# LATAM: 1.000000
# Dean: 1.000000
# Vocisano: 1.000000
# Australia: 1.000000
# Ready: 2.000000
# to: 4.000000
# get: 2.000000
# started?: 2.000000
# Contact: 1.000000
# Us: 1.000000
# Company: 2.000000
# Board: 4.000000
# Advisory: 2.000000
# Corporate: 2.000000
# Governance: 2.000000
# Resources: 2.000000
# Terms: 2.000000
# Conditions: 2.000000
# Privacy: 2.000000
# Policy: 2.000000
# Inglese: 2.000000
# Italiano: 2.000000
# Spagnolo: 2.000000
# Portoghese: 2.000000
# ©: 2.000000
# 2020: 5.000000
# DoveConviene: 3.000000
# S.R.L.: 2.000000
# VAT: 2.000000
# IT03156531208.: 2.000000
# Designed: 2.000000
# by: 2.000000
# Moze: 2.000000
# Mobile: 1.000000
# Store: 1.000000
# Miglioriamo: 1.000000
# experience: 1.000000
# nei: 4.000000
# fisici: 2.000000
# attraverso: 2.000000
# tecnologie: 1.000000
# digitali.: 1.000000
# retailer: 1.000000
# livello: 1.000000
# mondiale: 1.000000
# generare: 1.000000
# traffico: 1.000000
# Più: 1.000000
# 50: 1.000000
# persone: 1.000000
# consultano: 1.000000
# geolocalizzate: 1.000000
# cataloghi: 1.000000
# interattivi: 1.000000
# ed: 2.000000
# formati: 1.000000
# slide-to-store: 1.000000
# push: 1.000000
# proximity.: 1.000000
# Una: 1.000000
# volta: 1.000000
# trovato: 1.000000
# ciò: 1.000000
# hanno: 2.000000
# possono: 1.000000
# aggiungerlo: 1.000000
# preferiti: 1.000000
# attivare: 1.000000
# notifica: 1.000000
# remind: 1.000000
# li: 1.000000
# avviserà: 1.000000
# quando: 1.000000
# saranno: 1.000000
# vicini: 1.000000
# allo: 1.000000
# store: 2.000000
# valida: 1.000000
# l’offerta: 1.000000
# guidandoli: 1.000000
# quindi: 1.000000
# all’ingresso: 2.000000
# google: 1.000000
# play: 1.000000
# app: 2.000000
# Molto: 2.000000
# utile: 2.000000
# stars: 6.000000
# ben: 1.000000
# molto: 1.000000
# preparare: 1.000000
# tutti: 1.000000
# tipi: 1.000000
# controllare: 1.000000
# promozioni.: 1.000000
# —: 6.000000
# MI: 1.000000
# 🇮🇹: 2.000000
# Top: 1.000000
# App: 1.000000
# L’unica: 1.000000
# applicazione: 1.000000
# tipo: 1.000000
# dove: 1.000000
# puoi: 1.000000
# raccogliere: 1.000000
# velocemente: 1.000000
# informazioni: 1.000000
# circa: 1.000000
# ultime: 1.000000
# volantini: 1.000000
# nella: 1.000000
# tua: 1.000000
# zona: 1.000000
# Gabr37ele: 1.000000
# Love: 2.000000
# it: 4.000000
# I'd: 1.000000
# rather: 1.000000
# have: 1.000000
# ShopFully: 3.000000
# than: 1.000000
# junk: 1.000000
# mail: 1.000000
# I: 8.000000
# just: 1.000000
# put: 1.000000
# the: 3.000000
# bin: 1.000000
# each: 1.000000
# week.: 1.000000
# Ic: 1.000000
# covers: 1.000000
# all: 1.000000
# my: 1.000000
# needs: 1.000000
# when: 1.000000
# want: 1.000000
# them.: 1.000000
# Thanks: 1.000000
# for: 2.000000
# great: 2.000000
# App.: 1.000000
# Pebs57: 1.000000
# 🇧🇷: 1.000000
# Really: 1.000000
# good: 1.000000
# this: 1.000000
# use: 1.000000
# every: 1.000000
# week: 1.000000
# deals: 1.000000
# on: 1.000000
# pretty: 1.000000
# much: 1.000000
# everything: 1.000000
# anywhere: 1.000000
# want.: 1.000000
# Thanks.: 1.000000
# Sunnypunjab: 1.000000
# 🇦🇺: 2.000000
# Very: 1.000000
# useful: 2.000000
# can: 2.000000
# not: 1.000000
# do: 1.000000
# without: 1.000000
# it's: 1.000000
# find: 1.000000
# best: 1.000000
# offers: 1.000000
# win.: 1.000000
# Stefyx74: 1.000000
# Helpful: 1.000000
# It: 1.000000
# is: 3.000000
# very: 1.000000
# application.: 1.000000
# In: 1.000000
# addition: 1.000000
# also: 1.000000
# an: 1.000000
# ecological: 1.000000
# measure: 1.000000
# because: 1.000000
# paper: 1.000000
# saved.: 1.000000
# love!!!: 1.000000
# Lolilo6411: 1.000000
# 🇲🇽: 1.000000
# iphone: 1.000000
# image: 1.000000
# Retail: 1.000000
# solutions: 2.000000
# piattaforma: 1.000000
# offre: 1.000000
# centinaia: 1.000000
# soluzione: 2.000000
# loro: 1.000000
# generando: 1.000000
# visite: 2.000000
# negozio: 3.000000
# misurabili.: 1.000000
# Shopper: 1.000000
# advertising: 1.000000
# grado: 1.000000
# influenzare: 1.000000
# percorso: 1.000000
# acquisto: 1.000000
# fin: 1.000000
# dentro: 1.000000
# fisico.: 1.000000
# Measurement: 1.000000
# dati: 1.000000
# sono: 1.000000
# motore: 1.000000
# business.: 1.000000
# esperti: 1.000000
# dello: 1.000000
# omnicanale: 1.000000
# alla: 2.000000
# capacità: 1.000000
# prevedere: 1.000000
# misurare: 1.000000
# comportamento: 1.000000
# dall’esposizione: 1.000000
# messaggio: 1.000000
# pubblicitario: 1.000000
# successo: 1.000000
# numeri: 1.000000
# slideshow: 6.000000
# Paesi: 1.000000
# attivi: 1.000000
# nazionalità: 1.000000
# clienti: 1.000000
# scelto: 1.000000
# partner: 1.000000
# raggiunti: 1.000000
# monitorate: 1.000000
# Dal: 1.000000
# blog: 1.000000
# blog-post-thumb: 3.000000
# dm: 1.000000
# sceglie: 1.000000
# invitare: 1.000000
# scoprire: 1.000000
# propria: 1.000000
# offerta: 1.000000
# geolocalizzato: 1.000000
# ﻿: 1.000000
# Aprile: 1.000000
# Premiati: 1.000000
# 60: 1.000000
# prodotti: 1.000000
# innovativi: 1.000000
# 15a: 1.000000
# edizione: 1.000000
# italiana: 1.000000
# Eletto: 1.000000
# Prodotto: 1.000000
# Dell’Anno:: 1.000000
# oggi: 1.000000
# pa...: 1.000000
# Marzo: 2.000000
# Coronavirus:: 1.000000
# boom: 1.000000
# chi: 1.000000
# fa: 1.000000
# spesa: 1.000000
# lunedì: 1.000000
# martedì: 1.000000
# calo: 1.000000
# -60%: 1.000000
# weekend: 1.000000
# Contattaci: 1.000000

# %%
# Order by most recurrent words
content4 = content3.sortBy(lambda x: x[1], False)
content4.collect()
# Out:
# [('di', 30.0),
#  ('in', 21.0),
#  ('e', 12.0),
#  ('con', 11.0),
#  ('la', 11.0),
#  ('le', 9.0),
#  ('il', 9.0),
#  ('user-photo', 8.0),
#  ('&', 8.0),
#  ('I', 8.0),
#  ('a', 7.0),
#  ('per', 7.0),
#  ('più', 7.0),
#  ('milioni', 7.0),
#  ('shopping', 6.0),
#  ('i', 6.0),
#  ('del', 6.0),
#  ('stars', 6.0),
#  ('—', 6.0),
#  ('slideshow', 6.0),
#  ('Chi', 5.0),
#  ('siamo', 5.0),
#  ('Scopri', 5.0),
#  ('offerte', 5.0),
#  ('al', 5.0),
#  ('negozio.', 5.0),
#  ('2020', 5.0),
#  ('Lavora', 4.0),
#  ('noi', 4.0),
#  ('è', 4.0),
#  ('nostra', 4.0),
#  ('fino', 4.0),
#  ('retailers', 4.0),
#  ('shoppers', 4.0),
#  ('negozi', 4.0),
#  ('nostro', 4.0),
#  ('to', 4.0),
#  ('Board', 4.0),
#  ('nei', 4.0),
#  ('it', 4.0),
#  ('su', 3.0),
#  ('mobile', 3.0),
#  ('ai', 3.0),
#  ('nostri', 3.0),
#  ('migliore', 3.0),
#  ('che', 3.0),
#  ('nel', 3.0),
#  ('delle', 3.0),
#  ('cui', 3.0),
#  ('La', 3.0),
#  ('VP', 3.0),
#  ('Marketing', 3.0),
#  ('DoveConviene', 3.0),
#  ('ShopFully', 3.0),
#  ('the', 3.0),
#  ('is', 3.0),
#  ('negozio', 3.0),
#  ('blog-post-thumb', 3.0),
#  ('brand-logo', 2.0),
#  ('Homepage', 2.0),
#  ('Soluzioni', 2.0),
#  ('Contatti', 2.0),
#  ('Newsroom', 2.0),
#  ('Lo', 2.0),
#  ('passione.', 2.0),
#  ('Vogliamo', 2.0),
#  ('arricchire', 2.0),
#  ('questa', 2.0),
#  ('esperienza', 2.0),
#  ('dalla', 2.0),
#  ('fase', 2.0),
#  ('preparazione', 2.0),
#  ('momento', 2.0),
#  ('della', 2.0),
#  ('visita', 2.0),
#  ('sempre', 2.0),
#  ('efficace', 2.0),
#  ('Collaboriamo', 2.0),
#  ('manufacturers', 2.0),
#  ('gli', 2.0),
#  ('supportare', 2.0),
#  ('trasformazione', 2.0),
#  ('lo', 2.0),
#  ('grazie', 2.0),
#  ('modo', 2.0),
#  ('Siamo', 2.0),
#  ('come', 2.0),
#  ('una', 2.0),
#  ('2018', 2.0),
#  ('and', 2.0),
#  ('da', 2.0),
#  ('raggiungere', 2.0),
#  ('tutto', 2.0),
#  ('International', 2.0),
#  ('Per', 2.0),
#  ('questo', 2.0),
#  ('team', 2.0),
#  ('professionisti', 2.0),
#  ('6', 2.0),
#  ('uffici', 2.0),
#  ('Il', 2.0),
#  ('Stefano', 2.0),
#  ('Marco', 2.0),
#  ('Sales', 2.0),
#  ('Country', 2.0),
#  ('Manager', 2.0),
#  ('Ready', 2.0),
#  ('get', 2.0),
#  ('started?', 2.0),
#  ('Company', 2.0),
#  ('Advisory', 2.0),
#  ('Corporate', 2.0),
#  ('Governance', 2.0),
#  ('Resources', 2.0),
#  ('Terms', 2.0),
#  ('Conditions', 2.0),
#  ('Privacy', 2.0),
#  ('Policy', 2.0),
#  ('Inglese', 2.0),
#  ('Italiano', 2.0),
#  ('Spagnolo', 2.0),
#  ('Portoghese', 2.0),
#  ('©', 2.0),
#  ('S.R.L.', 2.0),
#  ('VAT', 2.0),
#  ('IT03156531208.', 2.0),
#  ('Designed', 2.0),
#  ('by', 2.0),
#  ('Moze', 2.0),
#  ('fisici', 2.0),
#  ('attraverso', 2.0),
#  ('ed', 2.0),
#  ('hanno', 2.0),
#  ('store', 2.0),
#  ('all’ingresso', 2.0),
#  ('app', 2.0),
#  ('Molto', 2.0),
#  ('utile', 2.0),
#  ('🇮🇹', 2.0),
#  ('Love', 2.0),
#  ('for', 2.0),
#  ('great', 2.0),
#  ('🇦🇺', 2.0),
#  ('useful', 2.0),
#  ('can', 2.0),
#  ('solutions', 2.0),
#  ('soluzione', 2.0),
#  ('visite', 2.0),
#  ('alla', 2.0),
#  ('Marzo', 2.0),
#  ('Shopping', 1.0),
#  ('Experts', 1.0),
#  ('partire', 1.0),
#  ('Ci', 1.0),
#  ('impegniamo', 1.0),
#  ('fondo', 1.0),
#  ('offrire', 1.0),
#  ('shopper', 1.0),
#  ('esperienza:', 1.0),
#  ('divertente.', 1.0),
#  ('numerosi', 1.0),
#  ('fine', 1.0),
#  ('condurre', 1.0),
#  ('Tech', 1.0),
#  ('Lovers', 1.0),
#  ('Crediamo', 1.0),
#  ('tecnologia', 1.0),
#  ('possa', 1.0),
#  ('realmente', 1.0),
#  ('guidare', 1.0),
#  ('processo', 1.0),
#  ('atto', 1.0),
#  ('modalità', 1.0),
#  ('consumatori', 1.0),
#  ('affrontano', 1.0),
#  ('shopping.', 1.0),
#  ('big', 1.0),
#  ('data', 1.0),
#  ('all’uso', 1.0),
#  ('machine', 1.0),
#  ('cerca', 1.0),
#  ('ogni', 1.0),
#  ('giorno', 1.0),
#  ('connettere', 1.0),
#  ('consumatori.', 1.0),
#  ('Entrepreneurs', 1.0),
#  ('riconosciuti', 1.0),
#  ('Europa', 1.0),
#  ('aziende', 1.0),
#  ('crescita', 1.0),
#  ('veloce', 1.0),
#  ('2017', 1.0),
#  ('(Inc.', 1.0),
#  ('5000', 1.0),
#  ('ma', 1.0),
#  ('abbiamo', 1.0),
#  ('ancora', 1.0),
#  ('molta', 1.0),
#  ('strada', 1.0),
#  ('fare.', 1.0),
#  ('prima', 1.0),
#  ('regola', 1.0),
#  ('obiettivi', 1.0),
#  ('concentrarsi', 1.0),
#  ('sulla', 1.0),
#  ('creazione', 1.0),
#  ('misurazione', 1.0),
#  ('valore', 1.0),
#  ('quello', 1.0),
#  ('facciamo.', 1.0),
#  ('Abbiamo', 1.0),
#  ('un’anima', 1.0),
#  ('internazionale.', 1.0),
#  ('Puntiamo', 1.0),
#  ('retail', 1.0),
#  ('mondo', 1.0),
#  ('proponendo', 1.0),
#  ('soluzioni', 1.0),
#  ('globali.', 1.0),
#  ('far', 1.0),
#  ('facciamo', 1.0),
#  ('affidamento', 1.0),
#  ('un', 1.0),
#  ('internazionale', 1.0),
#  ('200', 1.0),
#  ('16', 1.0),
#  ('differenti', 1.0),
#  ('operando', 1.0),
#  ('distribuiti', 1.0),
#  ('Apac', 1.0),
#  ('Latam.', 1.0),
#  ('management', 1.0),
#  ('Portu', 1.0),
#  ('CEO', 1.0),
#  ('Founder', 1.0),
#  ('Paolo', 1.0),
#  ('Gargiulo', 1.0),
#  ('HR', 1.0),
#  ('Director', 1.0),
#  ('Brambilla', 1.0),
#  ('Chief', 1.0),
#  ('Technology', 1.0),
#  ('Officer', 1.0),
#  ('Daniele', 1.0),
#  ('Antidormi', 1.0),
#  ('Business', 1.0),
#  ('Solutions', 1.0),
#  ('Davide', 1.0),
#  ('D’Alena', 1.0),
#  ('Durante', 1.0),
#  ('Italy', 1.0),
#  ('Clineu', 1.0),
#  ('Fernandes', 1.0),
#  ('Junior', 1.0),
#  ('LATAM', 1.0),
#  ('Dean', 1.0),
#  ('Vocisano', 1.0),
#  ('Australia', 1.0),
#  ('Contact', 1.0),
#  ('Us', 1.0),
#  ('Mobile', 1.0),
#  ('Store', 1.0),
#  ('Miglioriamo', 1.0),
#  ('experience', 1.0),
#  ('tecnologie', 1.0),
#  ('digitali.', 1.0),
#  ('retailer', 1.0),
#  ('livello', 1.0),
#  ('mondiale', 1.0),
#  ('generare', 1.0),
#  ('traffico', 1.0),
#  ('Più', 1.0),
#  ('50', 1.0),
#  ('persone', 1.0),
#  ('consultano', 1.0),
#  ('geolocalizzate', 1.0),
#  ('cataloghi', 1.0),
#  ('interattivi', 1.0),
#  ('formati', 1.0),
#  ('slide-to-store', 1.0),
#  ('push', 1.0),
#  ('proximity.', 1.0),
#  ('Una', 1.0),
#  ('volta', 1.0),
#  ('trovato', 1.0),
#  ('ciò', 1.0),
#  ('possono', 1.0),
#  ('aggiungerlo', 1.0),
#  ('preferiti', 1.0),
#  ('attivare', 1.0),
#  ('notifica', 1.0),
#  ('remind', 1.0),
#  ('li', 1.0),
#  ('avviserà', 1.0),
#  ('quando', 1.0),
#  ('saranno', 1.0),
#  ('vicini', 1.0),
#  ('allo', 1.0),
#  ('valida', 1.0),
#  ('l’offerta', 1.0),
#  ('guidandoli', 1.0),
#  ('quindi', 1.0),
#  ('google', 1.0),
#  ('play', 1.0),
#  ('ben', 1.0),
#  ('molto', 1.0),
#  ('preparare', 1.0),
#  ('tutti', 1.0),
#  ('tipi', 1.0),
#  ('controllare', 1.0),
#  ('promozioni.', 1.0),
#  ('MI', 1.0),
#  ('Top', 1.0),
#  ('App', 1.0),
#  ('L’unica', 1.0),
#  ('applicazione', 1.0),
#  ('tipo', 1.0),
#  ('dove', 1.0),
#  ('puoi', 1.0),
#  ('raccogliere', 1.0),
#  ('velocemente', 1.0),
#  ('informazioni', 1.0),
#  ('circa', 1.0),
#  ('ultime', 1.0),
#  ('volantini', 1.0),
#  ('nella', 1.0),
#  ('tua', 1.0),
#  ('zona', 1.0),
#  ('Gabr37ele', 1.0),
#  ("I'd", 1.0),
#  ('rather', 1.0),
#  ('have', 1.0),
#  ('than', 1.0),
#  ('junk', 1.0),
#  ('mail', 1.0),
#  ('just', 1.0),
#  ('put', 1.0),
#  ('bin', 1.0),
#  ('each', 1.0),
#  ('week.', 1.0),
#  ('Ic', 1.0),
#  ('covers', 1.0),
#  ('all', 1.0),
#  ('my', 1.0),
#  ('needs', 1.0),
#  ('when', 1.0),
#  ('want', 1.0),
#  ('them.', 1.0),
#  ('Thanks', 1.0),
#  ('App.', 1.0),
#  ('Pebs57', 1.0),
#  ('🇧🇷', 1.0),
#  ('Really', 1.0),
#  ('good', 1.0),
#  ('this', 1.0),
#  ('use', 1.0),
#  ('every', 1.0),
#  ('week', 1.0),
#  ('deals', 1.0),
#  ('on', 1.0),
#  ('pretty', 1.0),
#  ('much', 1.0),
#  ('everything', 1.0),
#  ('anywhere', 1.0),
#  ('want.', 1.0),
#  ('Thanks.', 1.0),
#  ('Sunnypunjab', 1.0),
#  ('Very', 1.0),
#  ('not', 1.0),
#  ('do', 1.0),
#  ('without', 1.0),
#  ("it's", 1.0),
#  ('find', 1.0),
#  ('best', 1.0),
#  ('offers', 1.0),
#  ('win.', 1.0),
#  ('Stefyx74', 1.0),
#  ('Helpful', 1.0),
#  ('It', 1.0),
#  ('very', 1.0),
#  ('application.', 1.0),
#  ('In', 1.0),
#  ('addition', 1.0),
#  ('also', 1.0),
#  ('an', 1.0),
#  ('ecological', 1.0),
#  ('measure', 1.0),
#  ('because', 1.0),
#  ('paper', 1.0),
#  ('saved.', 1.0),
#  ('love!!!', 1.0),
#  ('Lolilo6411', 1.0),
#  ('🇲🇽', 1.0),
#  ('iphone', 1.0),
#  ('image', 1.0),
#  ('Retail', 1.0),
#  ('piattaforma', 1.0),
#  ('offre', 1.0),
#  ('centinaia', 1.0),
#  ('loro', 1.0),
#  ('generando', 1.0),
#  ('misurabili.', 1.0),
#  ('Shopper', 1.0),
#  ('advertising', 1.0),
#  ('grado', 1.0),
#  ('influenzare', 1.0),
#  ('percorso', 1.0),
#  ('acquisto', 1.0),
#  ('fin', 1.0),
#  ('dentro', 1.0),
#  ('fisico.', 1.0),
#  ('Measurement', 1.0),
#  ('dati', 1.0),
#  ('sono', 1.0),
#  ('motore', 1.0),
#  ('business.', 1.0),
#  ('esperti', 1.0),
#  ('dello', 1.0),
#  ('omnicanale', 1.0),
#  ('capacità', 1.0),
#  ('prevedere', 1.0),
#  ('misurare', 1.0),
#  ('comportamento', 1.0),
#  ('dall’esposizione', 1.0),
#  ('messaggio', 1.0),
#  ('pubblicitario', 1.0),
#  ('successo', 1.0),
#  ('numeri', 1.0),
#  ('Paesi', 1.0),
#  ('attivi', 1.0),
#  ('nazionalità', 1.0),
#  ('clienti', 1.0),
#  ('scelto', 1.0),
#  ('partner', 1.0),
#  ('raggiunti', 1.0),
#  ('monitorate', 1.0),
#  ('Dal', 1.0),
#  ('blog', 1.0),
#  ('dm', 1.0),
#  ('sceglie', 1.0),
#  ('invitare', 1.0),
#  ('scoprire', 1.0),
#  ('propria', 1.0),
#  ('offerta', 1.0),
#  ('geolocalizzato', 1.0),
#  ('\ufeff', 1.0),
#  ('Aprile', 1.0),
#  ('Premiati', 1.0),
#  ('60', 1.0),
#  ('prodotti', 1.0),
#  ('innovativi', 1.0),
#  ('15a', 1.0),
#  ('edizione', 1.0),
#  ('italiana', 1.0),
#  ('Eletto', 1.0),
#  ('Prodotto', 1.0),
#  ('Dell’Anno:', 1.0),
#  ('oggi', 1.0),
#  ('pa...', 1.0),
#  ('Coronavirus:', 1.0),
#  ('boom', 1.0),
#  ('chi', 1.0),
#  ('fa', 1.0),
#  ('spesa', 1.0),
#  ('lunedì', 1.0),
#  ('martedì', 1.0),
#  ('calo', 1.0),
#  ('-60%', 1.0),
#  ('weekend', 1.0),
#  ('Contattaci', 1.0)]

# %%
content4.first()
# Out:
# ('di', 30.0)

# %%
content4.take(10)
# Out:
# [('di', 30.0),
#  ('in', 21.0),
#  ('e', 12.0),
#  ('con', 11.0),
#  ('la', 11.0),
#  ('le', 9.0),
#  ('il', 9.0),
#  ('user-photo', 8.0),
#  ('&', 8.0),
#  ('I', 8.0)]

# %%
accum_len = sc.accumulator(0)
accum_sum = sc.accumulator(0)

def set_accum(tuple_rdd):
    accum_sum.add(tuple_rdd[1])
    accum_len.add(1)

content4.foreach(set_accum)

# %%
accum_len.value
# Out:
# 470

# %%
accum_sum.value
# Out:
# 836.0

# %%
accum_sum.value/accum_len.value
# Out:
# 1.778723404255319

# %%
# Plain Python

tot_words = content4.collect()
tot_len = 0
tot_sum = 0

def calculate_mean(values):
    global tot_len, tot_sum
    
    for(word, occur) in values:
        tot_sum = tot_sum + occur
        tot_len = tot_len + 1
        
calculate_mean(tot_words)
print(tot_sum/tot_len)
# Out:
# 1.778723404255319
